# %%
import pandas as pd
import json

with open('results.json') as f:
    df=json.load(f)['DMD']
names={'up':'1-up','down':'2-down','combined':'3-combined'}
data=dict()
for i in ['2','5','10']:
    data[i]=[]
    for res in df[i]:
        # line={'r':i}
        line={}
        losses=res['losses']
        f_loss=dict()
        for k in ['compo-reg-','compo-dice-']:
            way=res['way']
            if way!='both':
                if way=='combined' or way=='both':
                    metrics='weighted' 
                    way='up'
                else:
                    metrics=way
                line['dice']=res['dice_'+metrics]*100
                line['hauss']=res['hauss_'+metrics]
                line['asd']=res['asd_'+metrics]
                # line['bidir-cons-reg']=losses['bidir-cons-reg']
                # line['bidir-cons-dice']=losses['bidir-cons-dice']
                f_loss[k[:-1]]=losses[k+way]            
                line['way']=names[res['way']]
                # del res['losses']
                line.update(f_loss)
                # for i,way in enumerate(['up','down','combined']):
                #     if way==line['way']: line['way']=f'{i}-{way}'
                data[i].append(line)

# for i in df.keys():
truc=pd.DataFrame(data['2'])
truc.sort_values('way',ascending=False,inplace=True)

table=truc.groupby(['compo-reg','compo-dice','way'],sort=True).mean()

for i in ['5','10']:
    if i!='2':
        truc=pd.DataFrame(data[i])
        truc.sort_values('way',ascending=False,inplace=True)

        truc=truc.groupby(['compo-reg','compo-dice','way'],sort=True).mean()
        table=pd.concat([table,truc],axis=1)
table#.to_excel('res_dmd_unidir.xlsx')
# Out:
#                                       dice     hauss       asd       dice  \
# compo-reg compo-dice way
# False     False      1-up        90.931857  2.598173  0.032753  87.946618
#                      2-down      90.974784  2.615040  0.040859  86.313486
#                      3-combined  92.308980  2.426594  0.024943  90.572995
#           True       1-up        92.963558  2.338274  0.026388  90.101081
#                      2-down      92.969686  2.179684  0.029281  89.764816
#                      3-combined  92.794019  2.334173  0.024436  90.918267
# True      False      1-up        90.927523  2.469397  0.033808  88.396561
#                      2-down      91.513419  2.541484  0.038514  86.860740
#                      3-combined  92.442125  2.278738  0.024694  90.672994
#           True       1-up        92.780852  2.310440  0.025020  90.448028
#                      2-down      93.445295  2.187530  0.024221  90.448093
#                      3-combined  92.732006  2.290981  0.021496  91.407424
#
#                                     hauss       asd       dice     hauss  \
# compo-reg compo-dice way
# False     False      1-up        3.218707  0.045971  82.566291  4.471128
#                      2-down      3.485373  0.053740  72.573429  6.668114
#                      3-combined  2.895235  0.034704  85.025519  3.889325
#           True       1-up        2.482012  0.038615  85.587937  3.643722
#                      2-down      3.025036  0.042191  83.872253  3.877804
#                      3-combined  2.608420  0.036665  86.889976  3.031348
# True      False      1-up        2.978458  0.045493  81.807709  4.500711
#                      2-down      3.364423  0.044860  80.306935  3.685043
#                      3-combined  2.779792  0.033233  86.427605  3.059908
#           True       1-up        2.563884  0.036484  86.270642  3.587459
#                      2-down      2.665276  0.030088  85.780847  3.666107
#                      3-combined  2.516688  0.030560  88.024956  3.003869
#
#                                       asd
# compo-reg compo-dice way
# False     False      1-up        0.059641
#                      2-down      0.360854
#                      3-combined  0.084016
#           True       1-up        0.055753
#                      2-down      0.047669
#                      3-combined  0.044370
# True      False      1-up        0.052841
#                      2-down      0.054450
#                      3-combined  0.036259
#           True       1-up        0.049013
#                      2-down      0.036123
#                      3-combined  0.034914

# %%
import pandas as pd
import json

with open('results.json') as f:
    df=json.load(f)['DMD']
names={'up':'1-up','down':'2-down','weighted':'3-combined'}
data=dict()
for i in ['2','5','10']:
    data[i]=[]
    for res in df[i]:
        # line={'r':i}
        line={}
        losses=res['losses']
        f_loss=dict()
        way=res['way']
        if way=='both':
            for metric in ['up','down','weighted']:
                line={}
                losses=res['losses']
                f_loss=dict()
                line['dice']=res['dice_'+metric]*100
                line['hauss']=res['hauss_'+metric]
                line['asd']=res['asd_'+metric]
                # line['bidir-cons-reg']=losses['bidir-cons-reg']
                # line['bidir-cons-dice']=losses['bidir-cons-dice']
                line['way']=names[metric]
                # del res['losses']
                line.update(f_loss)
                # for i,way in enumerate(['up','down','combined']):
                #     if way==line['way']: line['way']=f'{i}-{way}'
                data[i].append(line)
print(data['2'])
# for i in df.keys():
truc=pd.DataFrame(data['2'])
truc.sort_values('way',ascending=False,inplace=True)

table=truc.groupby(['way'],sort=True).mean()
table
for i in ['5','10']:
    if i!='2':
        truc=pd.DataFrame(data[i])
        truc.sort_values('way',ascending=False,inplace=True)

        truc=truc.groupby(['way'],sort=True).mean()
        table=pd.concat([table,truc],axis=1)
table#.to_excel('res_dmd_bidir.xlsx')
# Out:
# [{'dice': 93.00146698951721, 'hauss': 2.2899124066865286, 'asd': 0.028374665774520906, 'way': '1-up'}, {'dice': 93.37740540504456, 'hauss': 2.188410012413046, 'asd': 0.02561733313419, 'way': '2-down'}, {'dice': 92.83413290977478, 'hauss': 2.099999976765687, 'asd': 0.02360651487745365, 'way': '3-combined'}]
#                  dice     hauss       asd       dice     hauss       asd  \
# way
# 1-up        93.001467  2.289912  0.028375  90.841937  2.559494  0.033311
# 2-down      93.377405  2.188410  0.025617  90.374035  2.730124  0.032683
# 3-combined  92.834133  2.100000  0.023607  91.378564  2.582839  0.031043
#
#                  dice     hauss       asd
# way
# 1-up        86.640096  3.511729  0.051003
# 2-down      86.101484  3.688954  0.037748
# 3-combined  88.041443  3.036580  0.037512
